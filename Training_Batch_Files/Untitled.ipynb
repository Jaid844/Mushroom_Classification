# %%
import pandas as pd

# %%
data=pd.read_csv('mushroom_08012008_120012.csv')

# %%
data.rename(columns={'bruises%3F':'bruises'},inplace=True)

# %%
data
# Out:
#     cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         'x'         'y'       'g'     't'  'n'             'f'          'c'
# 1         'x'         'f'       'n'     't'  'n'             'f'          'c'
# 2         'f'         's'       'w'     'f'  'n'             'f'          'w'
# 3         'f'         'y'       'w'     't'  'p'             'f'          'c'
# 4         'f'         'y'       'n'     't'  'p'             'f'          'c'
# ..        ...         ...       ...     ...  ...             ...          ...
# 620       'x'         's'       'n'     'f'  'n'             'f'          'w'
# 621       'f'         'f'       'e'     't'  'n'             'f'          'c'
# 622       'f'         'f'       'w'     'f'  'n'             'f'          'w'
# 623       'f'         'f'       'g'     'f'  'n'             'f'          'w'
# 624       'x'         'y'       'e'     't'  'n'             'f'          'c'
#
# ...

# %%
data.to_csv('mushroom_08012008_120012.csv',index=False)
