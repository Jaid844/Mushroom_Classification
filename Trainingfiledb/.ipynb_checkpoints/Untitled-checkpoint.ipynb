# %%
import pandas as pd

# %%
data=pd.read_csv('Inputfile.csv')

# %%
data.isnull().any()
# Out:
# cap-shape                   False
# cap-surface                 False
# cap-color                   False
# bruises                     False
# odor                        False
# gill-attachment             False
# gill-spacing                False
# gill-color                  False
# gill-size                   False
# stalk-root                  False
# stalk-shape                 False
# stalk-surface-above-ring    False
# stalk-color-below-ring      False
# stalk-color-above-ring      False
# stalk-surface-below-ring    False
# veil-type                   False
# veil-color                  False
# ring-number                 False
# ring-type                   False
# spore-print-color           False
# population                  False
# habitat                     False
# class                       False
# dtype: bool

# %%
data["class"] = data["class"].map({'p': 1, 'e': 2})

# %%
data['class'].unique()
# Out:
# array(["'e'", "'p'"], dtype=object)

# %%
data['class']
# Out:
# 0      'e'
# 1      'e'
# 2      'p'
# 3      'e'
# 4      'e'
#       ...
# 620    'p'
# 621    'e'
# 622    'e'
# 623    'e'
# 624    'e'
# Name: class, Length: 625, dtype: object

# %%
mapping={'e':1,'p':2}

# %%
data['class']=data["class"].replace(mapping)

# %%
data['class']=data['class'].apply(appl)

# %%
def appl(column):
    if column=="'e'":
        return 1
    else:
        return 2

# %%
data['class'].value_counts()[1]
# Out:
# 556

# %%
data['class'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
data
# Out:
#     cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         'x'         'f'       'e'     't'  'n'             'f'          'c'
# 1         'x'         'f'       'n'     't'  'n'             'f'          'c'
# 2         'x'         'f'       'p'     'f'  'c'             'f'          'c'
# 3         'f'         'f'       'g'     't'  'n'             'f'          'c'
# 4         'x'         'y'       'n'     't'  'n'             'f'          'c'
# ..        ...         ...       ...     ...  ...             ...          ...
# 620       'x'         's'       'g'     'f'  'c'             'f'          'w'
# 621       'x'         'y'       'n'     't'  'n'             'f'          'c'
# 622       'x'         'y'       'n'     't'  'n'             'f'          'c'
# 623       'x'         'f'       'e'     't'  'n'             'f'          'c'
# 624       'x'         'f'       'g'     't'  'n'             'f'          'c'
#
# ...

# %%
data
# Out:
#     cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         'x'         'f'       'e'     't'  'n'             'f'          'c'
# 1         'x'         'f'       'n'     't'  'n'             'f'          'c'
# 2         'x'         'f'       'p'     'f'  'c'             'f'          'c'
# 3         'f'         'f'       'g'     't'  'n'             'f'          'c'
# 4         'x'         'y'       'n'     't'  'n'             'f'          'c'
# ..        ...         ...       ...     ...  ...             ...          ...
# 620       'x'         's'       'g'     'f'  'c'             'f'          'w'
# 621       'x'         'y'       'n'     't'  'n'             'f'          'c'
# 622       'x'         'y'       'n'     't'  'n'             'f'          'c'
# 623       'x'         'f'       'e'     't'  'n'             'f'          'c'
# 624       'x'         'f'       'g'     't'  'n'             'f'          'c'
#
# ...

# %%
data[data['class']==1]
# Out:
#     cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         'x'         'f'       'e'     't'  'n'             'f'          'c'
# 1         'x'         'f'       'n'     't'  'n'             'f'          'c'
# 3         'f'         'f'       'g'     't'  'n'             'f'          'c'
# 4         'x'         'y'       'n'     't'  'n'             'f'          'c'
# 5         'x'         'y'       'e'     't'  'n'             'f'          'c'
# ..        ...         ...       ...     ...  ...             ...          ...
# 619       'f'         'f'       'g'     't'  'n'             'f'          'c'
# 621       'x'         'y'       'n'     't'  'n'             'f'          'c'
# 622       'x'         'y'       'n'     't'  'n'             'f'          'c'
# 623       'x'         'f'       'e'     't'  'n'             'f'          'c'
# 624       'x'         'f'       'g'     't'  'n'             'f'          'c'
#
# ...

# %%
data[data['class']==2]
# Out:
#     cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 2         'x'         'f'       'p'     'f'  'c'             'f'          'c'
# 23        'x'         'y'       'y'     'f'  'f'             'f'          'c'
# 24        'x'         'f'       'g'     'f'  'f'             'f'          'c'
# 43        'x'         'f'       'p'     'f'  'c'             'f'          'w'
# 45        'x'         'f'       'g'     'f'  'f'             'f'          'c'
# ..        ...         ...       ...     ...  ...             ...          ...
# 597       'f'         'f'       'y'     'f'  'f'             'f'          'c'
# 603       'x'         's'       'g'     'f'  'c'             'f'          'c'
# 604       'x'         'f'       'g'     'f'  'f'             'f'          'c'
# 611       'f'         'f'       'y'     'f'  'f'             'f'          'c'
# 620       'x'         's'       'g'     'f'  'c'             'f'          'w'
#
# ...

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
X=data.drop('class',axis=1)

# %%
Y=data['class']

# %%
rus = RandomUnderSampler(random_state=42)

# %%
X_resampled, y_resampled = rus.fit_resample(X, Y)

# %%
balanced_data = pd.concat([X_resampled, y_resampled], axis=1)

# %%
balanced_data
# Out:
#     cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         'x'         'y'       'n'     't'  'n'             'f'          'c'
# 1         'f'         'f'       'n'     't'  'n'             'f'          'c'
# 2         'f'         'y'       'e'     't'  'n'             'f'          'c'
# 3         'x'         'y'       'n'     't'  'n'             'f'          'c'
# 4         'x'         'f'       'e'     't'  'n'             'f'          'c'
# ..        ...         ...       ...     ...  ...             ...          ...
# 133       'f'         'f'       'y'     'f'  'f'             'f'          'c'
# 134       'x'         's'       'g'     'f'  'c'             'f'          'c'
# 135       'x'         'f'       'g'     'f'  'f'             'f'          'c'
# 136       'f'         'f'       'y'     'f'  'f'             'f'          'c'
# 137       'x'         's'       'g'     'f'  'c'             'f'          'w'
#
# ...

# %%
balanced_data[balanced_data['class']==1]
# Out:
#    cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0        'x'         'y'       'n'     't'  'n'             'f'          'c'
# 1        'f'         'f'       'n'     't'  'n'             'f'          'c'
# 2        'f'         'y'       'e'     't'  'n'             'f'          'c'
# 3        'x'         'y'       'n'     't'  'n'             'f'          'c'
# 4        'x'         'f'       'e'     't'  'n'             'f'          'c'
# ..       ...         ...       ...     ...  ...             ...          ...
# 64       'f'         'f'       'e'     't'  'n'             'f'          'c'
# 65       'x'         'y'       'g'     't'  'n'             'f'          'c'
# 66       'x'         'f'       'g'     't'  'n'             'f'          'c'
# 67       'x'         'y'       'n'     't'  'n'             'f'          'c'
# 68       'f'         'y'       'g'     't'  'n'             'f'          'c'
#
# ...

# %%
balanced_data[balanced_data['class']==2]
# Out:
#     cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 69        'x'         'f'       'p'     'f'  'c'             'f'          'c'
# 70        'x'         'y'       'y'     'f'  'f'             'f'          'c'
# 71        'x'         'f'       'g'     'f'  'f'             'f'          'c'
# 72        'x'         'f'       'p'     'f'  'c'             'f'          'w'
# 73        'x'         'f'       'g'     'f'  'f'             'f'          'c'
# ..        ...         ...       ...     ...  ...             ...          ...
# 133       'f'         'f'       'y'     'f'  'f'             'f'          'c'
# 134       'x'         's'       'g'     'f'  'c'             'f'          'c'
# 135       'x'         'f'       'g'     'f'  'f'             'f'          'c'
# 136       'f'         'f'       'y'     'f'  'f'             'f'          'c'
# 137       'x'         's'       'g'     'f'  'c'             'f'          'w'
#
# ...
